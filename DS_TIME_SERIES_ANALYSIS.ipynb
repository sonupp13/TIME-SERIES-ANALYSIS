# %% [markdown]
# <a href="https://colab.research.google.com/github/sonupp13/TIME-SERIES-ANALYSIS/blob/main/DS_TIME_SERIES_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
apple_stock= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/aapl.csv',parse_dates=["Date"], index_col=["Date"])
apple_stock
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
apple_stock.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
apple_stock.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
apple_stock.loc["30-Jun-17"]   #specific date
# Out:
# Open           144.45
# High           144.96
# Low            143.78
# Close          144.02
# Volume    23024107.00
# Name: 2017-06-30 00:00:00, dtype: float64

# %%
apple_stock['2017-07']   #7th month
# Out:
# <ipython-input-40-84db15a94dac>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   apple_stock['2017-07']
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848

# %%
apple_stock['2017-01'].head()
# Out:
# <ipython-input-43-e1c0f988d55f>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   apple_stock['2017-01'].head()
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673

# %%
apple_stock.loc["2017-01"].Close.mean()  #average closing time price in january
# Out:
# 119.57000000000001

# %%
apple_stock['2016'].head()
# Out:
# <ipython-input-50-d62a34348adb>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   apple_stock['2016'].head()
#               Open    High     Low   Close    Volume
# Date
# 2016-12-30  116.65  117.20  115.43  115.82  30586265
# 2016-12-29  116.45  117.11  116.40  116.73  15039519
# 2016-12-28  117.52  118.02  116.20  116.76  20905892
# 2016-12-27  116.52  117.80  116.49  117.26  18296855
# 2016-12-23  115.59  116.52  115.59  116.52  14249484

# %%
apple_stock['2017-01-03':'2017-01-08']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
apple_stock['Open'].resample('M').mean()     # 'm' used to get monthways
# Out:
# Date
# 2016-07-31     99.422667
# 2016-08-31    107.462609
# 2016-09-30    110.673333
# 2016-10-31    115.743810
# 2016-11-30    110.098571
# 2016-12-31    113.995238
# 2017-01-31    119.093500
# 2017-02-28    133.234737
# 2017-03-31    140.361304
# 2017-04-30    143.030000
# 2017-05-31    151.965909
# 2017-06-30    148.215000
# 2017-07-31    143.622500
# Freq: M, Name: Open, dtype: float64

# %%
apple_stock['Close'].resample('M').mean()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
apple_stock['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
apple_stock['Close'].resample('M').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>
